# %%
#
# %cd /content
# !mkdir /content/dataset
# !mkdir /content/log
# !mkdir /content/train
#
# !git clone --branch dreambooth-advanced https://github.com/huggingface/diffusers
#
# !pip install accelerate==0.31.0
# !pip install datasets==2.19.0
# !pip install ftfy==6.2.0
# !pip install Jinja2==3.1.4
# !pip install peft==0.11.1
# !pip install tensorboard==2.15.2
# !pip install torchvision==0.18.0+cu121
# !pip install transformers==4.42.3
#
# %cd /content/diffusers
# !pip install -e .
#
# !accelerate config
#
# %cd /content/diffusers/examples/advanced_diffusion_training
# Out:
# /content
# Cloning into 'diffusers'...
# remote: Enumerating objects: 65621, done.
# remote: Counting objects: 100% (138/138), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 65621 (delta 53), reused 52 (delta 18), pack-reused 65483
# Receiving objects: 100% (65621/65621), 48.11 MiB | 8.72 MiB/s, done.
# Resolving deltas: 100% (48331/48331), done.
# Collecting accelerate==0.31.0
#   Downloading accelerate-0.31.0-py3-none-any.whl (309 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.31.0) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.31.0) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.31.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate==0.31.0) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.31.0) (2.3.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate==0.31.0) (0.23.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.31.0) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->accelerate==0.31.0)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->accelerate==0.31.0)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->accelerate==0.31.0)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10.0->accelerate==0.31.0)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->accelerate==0.31.0)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->accelerate==0.31.0)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->accelerate==0.31.0)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->accelerate==0.31.0)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->accelerate==0.31.0)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.10.0->accelerate==0.31.0)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->accelerate==0.31.0)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate==0.31.0)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 27.6 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate==0.31.0) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate==0.31.0) (4.66.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate==0.31.0) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate==0.31.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate==0.31.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate==0.31.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate==0.31.0) (2024.6.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate==0.31.0) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, accelerate
# Successfully installed accelerate-0.31.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105
# Collecting datasets==2.19.0
#   Downloading datasets-2.19.0-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets==2.19.0)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0) (4.66.4)
# Collecting xxhash (from datasets==2.19.0)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 9.7 MB/s eta 0:00:00
# Collecting multiprocess (from datasets==2.19.0)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0) (0.23.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.19.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.19.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.19.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.19.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.19.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.19.0) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets==2.19.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.19.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.19.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.19.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.19.0) (2024.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.19.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.19.0) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.19.0) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==2.19.0) (1.16.0)
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-2.19.0 dill-0.3.8 multiprocess-0.70.16 xxhash-3.4.1
# Collecting ftfy==6.2.0
#   Downloading ftfy-6.2.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy==6.2.0) (0.2.13)
# Installing collected packages: ftfy
# Successfully installed ftfy-6.2.0
# Requirement already satisfied: Jinja2==3.1.4 in /usr/local/lib/python3.10/dist-packages (3.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2==3.1.4) (2.1.5)
# Collecting peft==0.11.1
#   Downloading peft-0.11.1-py3-none-any.whl (251 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from peft==0.11.1) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from peft==0.11.1) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft==0.11.1) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from peft==0.11.1) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from peft==0.11.1) (2.3.0+cu121)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from peft==0.11.1) (4.41.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from peft==0.11.1) (4.66.4)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from peft==0.11.1) (0.31.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from peft==0.11.1) (0.4.3)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from peft==0.11.1) (0.23.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft==0.11.1) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft==0.11.1) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft==0.11.1) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft==0.11.1) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.11.1) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.11.1) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.11.1) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.11.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.11.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.11.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.11.1) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.11.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.11.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.11.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.11.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.11.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.11.1) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.11.1) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft==0.11.1) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->peft==0.11.1) (12.5.82)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->peft==0.11.1) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers->peft==0.11.1) (0.19.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->peft==0.11.1) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft==0.11.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft==0.11.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft==0.11.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft==0.11.1) (2024.6.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->peft==0.11.1) (1.3.0)
# Installing collected packages: peft
# Successfully installed peft-0.11.1
# Requirement already satisfied: tensorboard==2.15.2 in /usr/local/lib/python3.10/dist-packages (2.15.2)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.15.2) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.15.2) (1.64.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.15.2) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.15.2) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.15.2) (3.6)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.15.2) (1.25.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.15.2) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.15.2) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.15.2) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.15.2) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.15.2) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.15.2) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.15.2) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.15.2) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.15.2) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard==2.15.2) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard==2.15.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard==2.15.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard==2.15.2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard==2.15.2) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard==2.15.2) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard==2.15.2) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard==2.15.2) (3.2.2)
# Requirement already satisfied: torchvision==0.18.0+cu121 in /usr/local/lib/python3.10/dist-packages (0.18.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.18.0+cu121) (1.25.2)
# Requirement already satisfied: torch==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.18.0+cu121) (2.3.0+cu121)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.18.0+cu121) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision==0.18.0+cu121) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision==0.18.0+cu121) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision==0.18.0+cu121) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision==0.18.0+cu121) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision==0.18.0+cu121) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision==0.18.0+cu121) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision==0.18.0+cu121) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision==0.18.0+cu121) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision==0.18.0+cu121) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision==0.18.0+cu121) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision==0.18.0+cu121) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision==0.18.0+cu121) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision==0.18.0+cu121) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision==0.18.0+cu121) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision==0.18.0+cu121) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision==0.18.0+cu121) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision==0.18.0+cu121) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->torchvision==0.18.0+cu121) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.0->torchvision==0.18.0+cu121) (12.5.82)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.3.0->torchvision==0.18.0+cu121) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.3.0->torchvision==0.18.0+cu121) (1.3.0)
# Collecting transformers==4.42.3
#   Downloading transformers-4.42.3-py3-none-any.whl (9.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 22.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.42.3) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers==4.42.3) (0.23.4)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.42.3) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.42.3) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.42.3) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.42.3) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.42.3) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.42.3) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers==4.42.3) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.42.3) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.42.3) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.42.3) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.42.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.42.3) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.42.3) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.42.3) (2024.6.2)
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.41.2
#     Uninstalling transformers-4.41.2:
#       Successfully uninstalled transformers-4.41.2
# Successfully installed transformers-4.42.3
# /content/diffusers
# Obtaining file:///content/diffusers
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers==0.30.0.dev0) (8.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers==0.30.0.dev0) (3.15.4)
# Requirement already satisfied: huggingface-hub>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.30.0.dev0) (0.23.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from diffusers==0.30.0.dev0) (1.25.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.30.0.dev0) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers==0.30.0.dev0) (2.31.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.30.0.dev0) (0.4.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers==0.30.0.dev0) (9.4.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.2->diffusers==0.30.0.dev0) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.2->diffusers==0.30.0.dev0) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.2->diffusers==0.30.0.dev0) (6.0.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.2->diffusers==0.30.0.dev0) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.2->diffusers==0.30.0.dev0) (4.12.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers==0.30.0.dev0) (3.19.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.30.0.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.30.0.dev0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.30.0.dev0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.30.0.dev0) (2024.6.2)
# Building wheels for collected packages: diffusers
#   Building editable for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.30.0.dev0-0.editable-py3-none-any.whl size=11094 sha256=96c32e39df29b1c11b1c73c7b9fb04f589d2c418c890010b1231bbb599c9a795
#   Stored in directory: /tmp/pip-ephem-wheel-cache-bvubxvwf/wheels/95/c5/3b/e1b4269f8a2584de57e75f949a185b48fc4144e9a91fc9965a
# Successfully built diffusers
# Installing collected packages: diffusers
# Successfully installed diffusers-0.30.0.dev0
# ----------------------------------------------------------------------------------------------------In which compute environment are you running?
# Please input a choice index (starting from 0), and press enter
#  ➔  This machine
#     AWS (Amazon SageMaker)
# 0
# This machine
# ----------------------------------------------------------------------------------------------------Which type of machine are you using?
# Please input a choice index (starting from 0), and press enter
#  ➔  No distributed training
#     multi-CPU
#     multi-XPU
#     multi-GPU
#     multi-NPU
#     multi-MLU
#     TPU
# 0
# No distributed training
# Do you want to run your training on CPU only (even if a GPU / Apple Silicon / Ascend NPU device is available)? [yes/NO]:no
# Do you wish to optimize your script with torch dynamo?[yes/NO]:no
# Do you want to use DeepSpeed? [yes/NO]: no
# What GPU(s) (by id) should be used for training on this machine as a comma-seperated list? [all]:all
# Would you like to enable numa efficiency? (Currently only supported on NVIDIA hardware). [yes/NO]: no
# ----------------------------------------------------------------------------------------------------Do you wish to use FP16 or BF16 (mixed precision)?
# Please input a choice index (starting from 0), and press enter
#  ➔  no
#     fp16
#     bf16
#     fp8
# 1
# fp16
# accelerate configuration saved at /root/.cache/huggingface/accelerate/default_config.yaml
# /content/diffusers/examples/advanced_diffusion_training

# %%
#LOAD 10 IMAGES IN /content/dataset

# %%
# TRAIN TEXT ENCODER
#
# !accelerate launch --num_cpu_threads_per_process=1 train_dreambooth_lora_sd15_advanced.py \
  --adam_beta1=0.9 \
  --adam_beta2=0.999 \
  --adam_epsilon=1e-8 \
  --adam_weight_decay=0.01 \
  --checkpointing_steps=10 \
  --dataloader_num_workers=0 \
  --gradient_accumulation_steps=1 \
  --instance_data_dir="/content/dataset" \
  --instance_prompt="c4myl4" \
  --learning_rate=1e-4 \
  --logging_dir="/content/log" \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --max_grad_norm=1 \
  --max_train_steps=100 \
  --mixed_precision="fp16" \
  --optimizer="AdamW" \
  --output_dir="/content/train" \
  --pretrained_model_name_or_path="josemerinom/zero15" \
  --prior_loss_weight=1 \
  --rank=32 \
  --resolution=512 \
  --seed=0 \
  --text_encoder_lr=1e-4 \
  --train_batch_size=1 \
  --train_text_encoder \
  #
# Out:
# 2024-07-01 17:07:37.574871: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-01 17:07:37.574933: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-01 17:07:37.576329: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-01 17:07:37.590021: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-01 17:07:39.007929: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 07/01/2024 17:07:41 - INFO - __main__ - Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: fp16
#
# tokenizer/tokenizer_config.json: 100% 806/806 [00:00<00:00, 4.23MB/s]
# tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 7.92MB/s]
# tokenizer/merges.txt: 100% 525k/525k [00:00<00:00, 2.65MB/s]
# tokenizer/special_tokens_map.json: 100% 472/472 [00:00<00:00, 2.87MB/s]
# text_encoder/config.json: 100% 617/617 [00:00<00:00, 3.92MB/s]
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# scheduler/scheduler_config.json: 100% 308/308 [00:00<00:00, 1.88MB/s]
# {'timestep_spacing', 'thresholding', 'sample_max_value', 'rescale_betas_zero_snr', 'variance_type', 'clip_sample_range', 'dynamic_thresholding_ratio', 'prediction_type'} was not found in config. Values will be initialized to default values.
# model.safetensors: 100% 492M/492M [00:10<00:00, 46.9MB/s]
# vae/config.json: 100% 547/547 [00:00<00:00, 2.60MB/s]
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:02<00:00, 134MB/s]
# {'scaling_factor', 'use_post_quant_conv', 'shift_factor', 'latents_std', 'force_upcast', 'use_quant_conv', 'latents_mean'} was not found in config. Values will be initialized to default values.
# unet/config.json: 100% 743/743 [00:00<00:00, 4.52MB/s]
# diffusion_pytorch_model.safetensors: 100% 3.44G/3.44G [01:22<00:00, 41.4MB/s]
# {'addition_embed_type', 'class_embed_type', 'mid_block_only_cross_attention', 'class_embeddings_concat', 'addition_time_embed_dim', 'resnet_out_scale_factor', 'time_embedding_act_fn', 'reverse_transformer_layers_per_block', 'resnet_skip_time_act', 'attention_type', 'time_embedding_dim', 'resnet_time_scale_shift', 'conv_in_kernel', 'conv_out_kernel', 'timestep_post_act', 'num_class_embeds', 'upcast_attention', 'encoder_hid_dim', 'addition_embed_type_num_heads', 'mid_block_type', 'only_cross_attention', 'time_cond_proj_dim', 'time_embedding_type', 'encoder_hid_dim_type', 'dropout', 'dual_cross_attention', 'use_linear_projection', 'projection_class_embeddings_input_dim', 'cross_attention_norm', 'transformer_layers_per_block', 'num_attention_heads'} was not found in config. Values will be initialized to default values.
# validation prompt: None
# 07/01/2024 17:09:25 - INFO - __main__ - ***** Running training *****
# 07/01/2024 17:09:25 - INFO - __main__ -   Num examples = 10
# 07/01/2024 17:09:25 - INFO - __main__ -   Num batches each epoch = 10
# 07/01/2024 17:09:25 - INFO - __main__ -   Num Epochs = 10
# 07/01/2024 17:09:25 - INFO - __main__ -   Instantaneous batch size per device = 1
# 07/01/2024 17:09:25 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 1
# 07/01/2024 17:09:25 - INFO - __main__ -   Gradient Accumulation steps = 1
# 07/01/2024 17:09:25 - INFO - __main__ -   Total optimization steps = 100
# Steps:  10% 10/100 [00:08<00:49,  1.81it/s, loss=0.00326, lr=0.0001]07/01/2024 17:09:34 - INFO - accelerate.accelerator - Saving current state to /content/train/checkpoint-10
# Traceback (most recent call last):
#   File "/content/diffusers/examples/advanced_diffusion_training/train_dreambooth_lora_sd15_advanced.py", line 2012, in <module>
#     main(args)
#   File "/content/diffusers/examples/advanced_diffusion_training/train_dreambooth_lora_sd15_advanced.py", line 1802, in main
#     accelerator.save_state(save_path)
#   File "/usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py", line 2955, in save_state
#     hook(self._models, weights, output_dir)
#   File "/content/diffusers/examples/advanced_diffusion_training/train_dreambooth_lora_sd15_advanced.py", line 1293, in save_model_hook
#     raise ValueError(f"unexpected save model: {model.__class__}")
# ValueError: unexpected save model: <class 'transformers.models.clip.modeling_clip.CLIPTextModel'>
# Steps:  10% 10/100 [00:08<01:20,  1.12it/s, loss=0.00326, lr=0.0001]
# Traceback (most recent call last):
#   File "/usr/local/bin/accelerate", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/accelerate/commands/accelerate_cli.py", line 48, in main
#     args.func(args)
#   File "/usr/local/lib/python3.10/dist-packages/accelerate/commands/launch.py", line 1097, in launch_command
#     simple_launcher(args)
#   File "/usr/local/lib/python3.10/dist-packages/accelerate/commands/launch.py", line 703, in simple_launcher
#     raise subprocess.CalledProcessError(returncode=process.returncode, cmd=cmd)
# subprocess.CalledProcessError: Command '['/usr/bin/python3', 'train_dreambooth_lora_sd15_advanced.py', '--adam_beta1=0.9', '--adam_beta2=0.999', '--adam_epsilon=1e-8', '--adam_weight_decay=0.01', '--checkpointing_steps=10', '--dataloader_num_workers=0', '--gradient_accumulation_steps=1', '--instance_data_dir=/content/dataset', '--instance_prompt=c4myl4', '--learning_rate=1e-4', '--logging_dir=/content/log', '--lr_scheduler=constant', '--lr_warmup_steps=0', '--max_grad_norm=1', '--max_train_steps=100', '--mixed_precision=fp16', '--optimizer=AdamW', '--output_dir=/content/train', '--pretrained_model_name_or_path=josemerinom/zero15', '--prior_loss_weight=1', '--rank=32', '--resolution=512', '--seed=0', '--text_encoder_lr=1e-4', '--train_batch_size=1', '--train_text_encoder']' returned non-zero exit status 1.

# %%
# NO TRAIN TEXT ENCODER
#
# !accelerate launch --num_cpu_threads_per_process=1 train_dreambooth_lora_sd15_advanced.py \
  --adam_beta1=0.9 \
  --adam_beta2=0.999 \
  --adam_epsilon=1e-8 \
  --adam_weight_decay=0.01 \
  --checkpointing_steps=10 \
  --dataloader_num_workers=0 \
  --gradient_accumulation_steps=1 \
  --instance_data_dir="/content/dataset" \
  --instance_prompt="c4myl4" \
  --learning_rate=1e-4 \
  --logging_dir="/content/log" \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --max_grad_norm=1 \
  --max_train_steps=100 \
  --mixed_precision="fp16" \
  --optimizer="AdamW" \
  --output_dir="/content/train" \
  --pretrained_model_name_or_path="josemerinom/zero15" \
  --prior_loss_weight=1 \
  --rank=32 \
  --resolution=512 \
  --seed=0 \
  --text_encoder_lr=1e-4 \
  --train_batch_size=1 \
  #
  #--train_text_encoder \
# Out:
# 2024-07-01 17:10:11.616174: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-01 17:10:11.616233: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-01 17:10:11.617573: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-01 17:10:11.624794: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-01 17:10:12.735023: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 07/01/2024 17:10:15 - INFO - __main__ - Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: fp16
#
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# {'prediction_type', 'clip_sample_range', 'sample_max_value', 'dynamic_thresholding_ratio', 'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# {'latents_mean', 'latents_std', 'use_quant_conv', 'use_post_quant_conv', 'shift_factor', 'force_upcast', 'scaling_factor'} was not found in config. Values will be initialized to default values.
# {'mid_block_type', 'addition_time_embed_dim', 'conv_out_kernel', 'projection_class_embeddings_input_dim', 'dropout', 'transformer_layers_per_block', 'addition_embed_type_num_heads', 'resnet_time_scale_shift', 'mid_block_only_cross_attention', 'conv_in_kernel', 'reverse_transformer_layers_per_block', 'encoder_hid_dim', 'addition_embed_type', 'upcast_attention', 'only_cross_attention', 'timestep_post_act', 'class_embed_type', 'attention_type', 'dual_cross_attention', 'use_linear_projection', 'time_cond_proj_dim', 'resnet_skip_time_act', 'encoder_hid_dim_type', 'num_attention_heads', 'cross_attention_norm', 'num_class_embeds', 'resnet_out_scale_factor', 'class_embeddings_concat', 'time_embedding_dim', 'time_embedding_type', 'time_embedding_act_fn'} was not found in config. Values will be initialized to default values.
# validation prompt: None
# 07/01/2024 17:10:29 - INFO - __main__ - ***** Running training *****
# 07/01/2024 17:10:29 - INFO - __main__ -   Num examples = 10
# 07/01/2024 17:10:29 - INFO - __main__ -   Num batches each epoch = 10
# 07/01/2024 17:10:29 - INFO - __main__ -   Num Epochs = 10
# 07/01/2024 17:10:29 - INFO - __main__ -   Instantaneous batch size per device = 1
# 07/01/2024 17:10:29 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 1
# 07/01/2024 17:10:29 - INFO - __main__ -   Gradient Accumulation steps = 1
# 07/01/2024 17:10:29 - INFO - __main__ -   Total optimization steps = 100
# Steps:  10% 10/100 [00:05<00:44,  2.04it/s, loss=0.00349, lr=0.0001]07/01/2024 17:10:34 - INFO - accelerate.accelerator - Saving current state to /content/train/checkpoint-10
# Model weights saved in /content/train/checkpoint-10/pytorch_lora_weights.safetensors
# 07/01/2024 17:10:34 - INFO - accelerate.checkpointing - Optimizer state saved in /content/train/checkpoint-10/optimizer.bin
# 07/01/2024 17:10:34 - INFO - accelerate.checkpointing - Scheduler state saved in /content/train/checkpoint-10/scheduler.bin
# 07/01/2024 17:10:34 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/train/checkpoint-10/sampler.bin
# 07/01/2024 17:10:34 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/train/checkpoint-10/scaler.pt
# 07/01/2024 17:10:34 - INFO - accelerate.checkpointing - Random states saved in /content/train/checkpoint-10/random_states_0.pkl
# 07/01/2024 17:10:34 - INFO - __main__ - Saved state to /content/train/checkpoint-10
# Steps:  20% 20/100 [00:10<00:39,  2.04it/s, loss=0.0934, lr=0.0001]07/01/2024 17:10:39 - INFO - accelerate.accelerator - Saving current state to /content/train/checkpoint-20
# Model weights saved in /content/train/checkpoint-20/pytorch_lora_weights.safetensors
# 07/01/2024 17:10:40 - INFO - accelerate.checkpointing - Optimizer state saved in /content/train/checkpoint-20/optimizer.bin
# 07/01/2024 17:10:40 - INFO - accelerate.checkpointing - Scheduler state saved in /content/train/checkpoint-20/scheduler.bin
# 07/01/2024 17:10:40 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/train/checkpoint-20/sampler.bin
# 07/01/2024 17:10:40 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/train/checkpoint-20/scaler.pt
# 07/01/2024 17:10:40 - INFO - accelerate.checkpointing - Random states saved in /content/train/checkpoint-20/random_states_0.pkl
# 07/01/2024 17:10:40 - INFO - __main__ - Saved state to /content/train/checkpoint-20
# Steps:  30% 30/100 [00:15<00:34,  2.02it/s, loss=0.0687, lr=0.0001]07/01/2024 17:10:45 - INFO - accelerate.accelerator - Saving current state to /content/train/checkpoint-30
# Model weights saved in /content/train/checkpoint-30/pytorch_lora_weights.safetensors
# 07/01/2024 17:10:45 - INFO - accelerate.checkpointing - Optimizer state saved in /content/train/checkpoint-30/optimizer.bin
# 07/01/2024 17:10:45 - INFO - accelerate.checkpointing - Scheduler state saved in /content/train/checkpoint-30/scheduler.bin
# 07/01/2024 17:10:45 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/train/checkpoint-30/sampler.bin
# 07/01/2024 17:10:45 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/train/checkpoint-30/scaler.pt
# 07/01/2024 17:10:45 - INFO - accelerate.checkpointing - Random states saved in /content/train/checkpoint-30/random_states_0.pkl
# 07/01/2024 17:10:45 - INFO - __main__ - Saved state to /content/train/checkpoint-30
# Steps:  40% 40/100 [00:21<00:29,  2.01it/s, loss=0.0078, lr=0.0001]07/01/2024 17:10:50 - INFO - accelerate.accelerator - Saving current state to /content/train/checkpoint-40
# Model weights saved in /content/train/checkpoint-40/pytorch_lora_weights.safetensors
# 07/01/2024 17:10:50 - INFO - accelerate.checkpointing - Optimizer state saved in /content/train/checkpoint-40/optimizer.bin
# 07/01/2024 17:10:50 - INFO - accelerate.checkpointing - Scheduler state saved in /content/train/checkpoint-40/scheduler.bin
# 07/01/2024 17:10:50 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/train/checkpoint-40/sampler.bin
# 07/01/2024 17:10:50 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/train/checkpoint-40/scaler.pt
# 07/01/2024 17:10:50 - INFO - accelerate.checkpointing - Random states saved in /content/train/checkpoint-40/random_states_0.pkl
# 07/01/2024 17:10:50 - INFO - __main__ - Saved state to /content/train/checkpoint-40
# Steps:  50% 50/100 [00:26<00:25,  1.99it/s, loss=0.0237, lr=0.0001]07/01/2024 17:10:55 - INFO - accelerate.accelerator - Saving current state to /content/train/checkpoint-50
# Model weights saved in /content/train/checkpoint-50/pytorch_lora_weights.safetensors
# 07/01/2024 17:10:55 - INFO - accelerate.checkpointing - Optimizer state saved in /content/train/checkpoint-50/optimizer.bin
# 07/01/2024 17:10:55 - INFO - accelerate.checkpointing - Scheduler state saved in /content/train/checkpoint-50/scheduler.bin
# 07/01/2024 17:10:55 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/train/checkpoint-50/sampler.bin
# 07/01/2024 17:10:55 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/train/checkpoint-50/scaler.pt
# 07/01/2024 17:10:55 - INFO - accelerate.checkpointing - Random states saved in /content/train/checkpoint-50/random_states_0.pkl
# 07/01/2024 17:10:55 - INFO - __main__ - Saved state to /content/train/checkpoint-50
# Steps:  60% 60/100 [00:31<00:20,  1.98it/s, loss=0.111, lr=0.0001]07/01/2024 17:11:00 - INFO - accelerate.accelerator - Saving current state to /content/train/checkpoint-60
# Model weights saved in /content/train/checkpoint-60/pytorch_lora_weights.safetensors
# 07/01/2024 17:11:00 - INFO - accelerate.checkpointing - Optimizer state saved in /content/train/checkpoint-60/optimizer.bin
# 07/01/2024 17:11:00 - INFO - accelerate.checkpointing - Scheduler state saved in /content/train/checkpoint-60/scheduler.bin
# 07/01/2024 17:11:00 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/train/checkpoint-60/sampler.bin
# 07/01/2024 17:11:00 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/train/checkpoint-60/scaler.pt
# 07/01/2024 17:11:00 - INFO - accelerate.checkpointing - Random states saved in /content/train/checkpoint-60/random_states_0.pkl
# 07/01/2024 17:11:00 - INFO - __main__ - Saved state to /content/train/checkpoint-60
# Steps:  70% 70/100 [00:36<00:15,  1.95it/s, loss=0.0747, lr=0.0001]07/01/2024 17:11:06 - INFO - accelerate.accelerator - Saving current state to /content/train/checkpoint-70
# Model weights saved in /content/train/checkpoint-70/pytorch_lora_weights.safetensors
# 07/01/2024 17:11:06 - INFO - accelerate.checkpointing - Optimizer state saved in /content/train/checkpoint-70/optimizer.bin
# 07/01/2024 17:11:06 - INFO - accelerate.checkpointing - Scheduler state saved in /content/train/checkpoint-70/scheduler.bin
# 07/01/2024 17:11:06 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/train/checkpoint-70/sampler.bin
# 07/01/2024 17:11:06 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/train/checkpoint-70/scaler.pt
# 07/01/2024 17:11:06 - INFO - accelerate.checkpointing - Random states saved in /content/train/checkpoint-70/random_states_0.pkl
# 07/01/2024 17:11:06 - INFO - __main__ - Saved state to /content/train/checkpoint-70
# Steps:  80% 80/100 [00:42<00:10,  1.93it/s, loss=0.0143, lr=0.0001]07/01/2024 17:11:11 - INFO - accelerate.accelerator - Saving current state to /content/train/checkpoint-80
# Model weights saved in /content/train/checkpoint-80/pytorch_lora_weights.safetensors
# 07/01/2024 17:11:11 - INFO - accelerate.checkpointing - Optimizer state saved in /content/train/checkpoint-80/optimizer.bin
# 07/01/2024 17:11:11 - INFO - accelerate.checkpointing - Scheduler state saved in /content/train/checkpoint-80/scheduler.bin
# 07/01/2024 17:11:11 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/train/checkpoint-80/sampler.bin
# 07/01/2024 17:11:11 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/train/checkpoint-80/scaler.pt
# 07/01/2024 17:11:11 - INFO - accelerate.checkpointing - Random states saved in /content/train/checkpoint-80/random_states_0.pkl
# 07/01/2024 17:11:11 - INFO - __main__ - Saved state to /content/train/checkpoint-80
# Steps:  90% 90/100 [00:47<00:05,  1.93it/s, loss=0.0956, lr=0.0001]07/01/2024 17:11:16 - INFO - accelerate.accelerator - Saving current state to /content/train/checkpoint-90
# Model weights saved in /content/train/checkpoint-90/pytorch_lora_weights.safetensors
# 07/01/2024 17:11:17 - INFO - accelerate.checkpointing - Optimizer state saved in /content/train/checkpoint-90/optimizer.bin
# 07/01/2024 17:11:17 - INFO - accelerate.checkpointing - Scheduler state saved in /content/train/checkpoint-90/scheduler.bin
# 07/01/2024 17:11:17 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/train/checkpoint-90/sampler.bin
# 07/01/2024 17:11:17 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/train/checkpoint-90/scaler.pt
# 07/01/2024 17:11:17 - INFO - accelerate.checkpointing - Random states saved in /content/train/checkpoint-90/random_states_0.pkl
# 07/01/2024 17:11:17 - INFO - __main__ - Saved state to /content/train/checkpoint-90
# Steps: 100% 100/100 [00:53<00:00,  1.90it/s, loss=0.0161, lr=0.0001]07/01/2024 17:11:22 - INFO - accelerate.accelerator - Saving current state to /content/train/checkpoint-100
# Model weights saved in /content/train/checkpoint-100/pytorch_lora_weights.safetensors
# 07/01/2024 17:11:22 - INFO - accelerate.checkpointing - Optimizer state saved in /content/train/checkpoint-100/optimizer.bin
# 07/01/2024 17:11:22 - INFO - accelerate.checkpointing - Scheduler state saved in /content/train/checkpoint-100/scheduler.bin
# 07/01/2024 17:11:22 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in /content/train/checkpoint-100/sampler.bin
# 07/01/2024 17:11:22 - INFO - accelerate.checkpointing - Gradient scaler state saved in /content/train/checkpoint-100/scaler.pt
# 07/01/2024 17:11:22 - INFO - accelerate.checkpointing - Random states saved in /content/train/checkpoint-100/random_states_0.pkl
# 07/01/2024 17:11:22 - INFO - __main__ - Saved state to /content/train/checkpoint-100
# Steps: 100% 100/100 [00:53<00:00,  1.90it/s, loss=0.0148, lr=0.0001]Model weights saved in /content/train/pytorch_lora_weights.safetensors
# Traceback (most recent call last):
#   File "/content/diffusers/examples/advanced_diffusion_training/train_dreambooth_lora_sd15_advanced.py", line 2012, in <module>
#     main(args)
#   File "/content/diffusers/examples/advanced_diffusion_training/train_dreambooth_lora_sd15_advanced.py", line 1984, in main
#     save_file(kohya_state_dict, f"{args.output_dir}/{args.output_dir}.safetensors")
#   File "/usr/local/lib/python3.10/dist-packages/safetensors/torch.py", line 284, in save_file
#     serialize_file(_flatten(tensors), filename, metadata=metadata)
# safetensors_rust.SafetensorError: Error while serializing: IoError(Os { code: 2, kind: NotFound, message: "No such file or directory" })
# Steps: 100% 100/100 [00:53<00:00,  1.86it/s, loss=0.0148, lr=0.0001]
# Traceback (most recent call last):
#   File "/usr/local/bin/accelerate", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/accelerate/commands/accelerate_cli.py", line 48, in main
#     args.func(args)
#   File "/usr/local/lib/python3.10/dist-packages/accelerate/commands/launch.py", line 1097, in launch_command
#     simple_launcher(args)
#   File "/usr/local/lib/python3.10/dist-packages/accelerate/commands/launch.py", line 703, in simple_launcher
#     raise subprocess.CalledProcessError(returncode=process.returncode, cmd=cmd)
# subprocess.CalledProcessError: Command '['/usr/bin/python3', 'train_dreambooth_lora_sd15_advanced.py', '--adam_beta1=0.9', '--adam_beta2=0.999', '--adam_epsilon=1e-8', '--adam_weight_decay=0.01', '--checkpointing_steps=10', '--dataloader_num_workers=0', '--gradient_accumulation_steps=1', '--instance_data_dir=/content/dataset', '--instance_prompt=c4myl4', '--learning_rate=1e-4', '--logging_dir=/content/log', '--lr_scheduler=constant', '--lr_warmup_steps=0', '--max_grad_norm=1', '--max_train_steps=100', '--mixed_precision=fp16', '--optimizer=AdamW', '--output_dir=/content/train', '--pretrained_model_name_or_path=josemerinom/zero15', '--prior_loss_weight=1', '--rank=32', '--resolution=512', '--seed=0', '--text_encoder_lr=1e-4', '--train_batch_size=1']' returned non-zero exit status 1.

# %%
# !diffusers-cli env
# Out:
# Copy-and-paste the text below in your GitHub issue and FILL OUT the two last points.
#
# - 🤗 Diffusers version: 0.30.0.dev0
# - Platform: Linux-6.1.85+-x86_64-with-glibc2.35
# - Running on a notebook?: No
# - Running on Google Colab?: No
# - Python version: 3.10.12
# - PyTorch version (GPU?): 2.3.0+cu121 (True)
# - Flax version (CPU?/GPU?/TPU?): 0.8.4 (gpu)
# - Jax version: 0.4.26
# - JaxLib version: 0.4.26
# - Huggingface_hub version: 0.23.4
# - Transformers version: 4.42.3
# - Accelerate version: 0.31.0
# - PEFT version: 0.11.1
# - Bitsandbytes version: not installed
# - Safetensors version: 0.4.3
# - xFormers version: not installed
# - Accelerator: Tesla T4, 15360 MiB VRAM
# - Using GPU in script?: <fill in>
# - Using distributed or parallel set-up in script?: <fill in>
